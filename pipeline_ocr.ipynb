# %% [markdown]
# # Chuẩn bị dữ liệu

# %%
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1j_0RvUWpFchxW4BaZERrJx7oZOz7tFc4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown) (3.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.6.0
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1j_0RvUWpFchxW4BaZERrJx7oZOz7tFc4
# To: /content/data_ocr.zip
# 100% 370M/370M [00:04<00:00, 85.5MB/s]

# %%
# !unzip data_ocr.zip
# Out:
# Archive:  data_ocr.zip
#    creating: data_ocr/
#  extracting: data_ocr/0000_samples.png
#  extracting: data_ocr/0001_samples.png
#  extracting: data_ocr/0002_samples.png
#  extracting: data_ocr/0003_samples.png
#  extracting: data_ocr/0004_samples.png
#  extracting: data_ocr/0005_samples.png
#  extracting: data_ocr/0006_samples.png
#  extracting: data_ocr/0007_samples.png
#  extracting: data_ocr/0008_samples.png
#  extracting: data_ocr/0009_samples.png
#  extracting: data_ocr/0010_samples.png
#  extracting: data_ocr/0011_samples.png
#  extracting: data_ocr/0012_samples.png
#  extracting: data_ocr/0013_samples.png
#  extracting: data_ocr/0014_samples.png
#  extracting: data_ocr/0015_samples.png
#  extracting: data_ocr/0016_samples.png
#  extracting: data_ocr/0017_samples.png
#  extracting: data_ocr/0018_samples.png
#  extracting: data_ocr/0019_samples.png
#   inflating: data_ocr/0020_samples.png
#  extracting: data_ocr/0021_samples.png
#  extracting: data_ocr/0022_samples.png
#  extracting: data_ocr/0023_samples.png
#  extracting: data_ocr/0024_samples.png
#   inflating: data_ocr/0025_samples.png
#  extracting: data_ocr/0026_samples.png
#  extracting: data_ocr/0027_samples.png
#  extracting: data_ocr/0028_samples.png
#  extracting: data_ocr/0029_samples.png
#  extracting: data_ocr/0030_samples.png
#   inflating: data_ocr/0031_samples.png
#   inflating: data_ocr/0032_samples.png
#  extracting: data_ocr/0033_samples.png
#  extracting: data_ocr/0034_samples.png
#  extracting: data_ocr/0035_samples.png
#  extracting: data_ocr/0036_samples.png
#  extracting: data_ocr/0037_samples.png
#  extracting: data_ocr/0038_samples.png
#  extracting: data_ocr/0039_samples.png
#  extracting: data_ocr/0040_samples.png
#  extracting: data_ocr/0041_samples.png
#  extracting: data_ocr/0042_samples.png
#  extracting: data_ocr/0043_samples.png
#   inflating: data_ocr/0044_samples.png
#  extracting: data_ocr/0045_samples.png
#  extracting: data_ocr/0046_samples.png
#  extracting: data_ocr/0047_samples.png
#  extracting: data_ocr/0048_samples.png
#  extracting: data_ocr/0049_samples.png
#  extracting: data_ocr/0050_samples.png
#  extracting: data_ocr/0051_samples.png
#  extracting: data_ocr/0052_samples.png
#  extracting: data_ocr/0053_samples.png
#  extracting: data_ocr/0054_samples.png
#  extracting: data_ocr/0055_samples.png
#  extracting: data_ocr/0056_samples.png
#   inflating: data_ocr/0057_samples.png
#  extracting: data_ocr/0058_samples.png
#  extracting: data_ocr/0059_samples.png
#  extracting: data_ocr/0060_samples.png
#  extracting: data_ocr/0061_samples.png
#  extracting: data_ocr/0062_samples.png
#  extracting: data_ocr/0063_samples.png
#  extracting: data_ocr/0064_samples.png
#  extracting: data_ocr/0065_samples.png
#  extracting: data_ocr/0066_samples.png
#  extracting: data_ocr/0067_samples.png
#  extracting: data_ocr/0068_samples.png
#  extracting: data_ocr/0069_samples.png
#  extracting: data_ocr/0070_samples.png
#  extracting: data_ocr/0071_samples.png
#  extracting: data_ocr/0072_samples.png
#  extracting: data_ocr/0073_samples.png
#  extracting: data_ocr/0074_samples.png
#   inflating: data_ocr/0075_samples.png
#  extracting: data_ocr/0076_samples.png
#  extracting: data_ocr/0077_samples.png
#  extracting: data_ocr/0078_samples.png
#  extracting: data_ocr/0079_samples.png
#  extracting: data_ocr/0080_samples.png
#  extracting: data_ocr/0081_samples.png
#  extracting: data_ocr/0082_samples.png
#  extracting: data_ocr/0083_samples.png
#  extracting: data_ocr/0084_samples.png
#  extracting: data_ocr/0085_samples.png
#  extracting: data_ocr/0086_samples.png
#  extracting: data_ocr/0087_samples.png
#  extracting: data_ocr/0088_samples.png
#  extracting: data_ocr/0089_samples.png
#  extracting: data_ocr/0090_samples.png
#  extracting: data_ocr/0091_samples.png
#  extracting: data_ocr/0092_samples.png
#  extracting: data_ocr/0093_samples.png
#  extracting: data_ocr/0094_samples.png
#  extracting: data_ocr/0095_samples.png
#  extracting: data_ocr/0096_samples.png
#  extracting: data_ocr/0097_samples.png
#   inflating: data_ocr/0098_samples.png
#   inflating: data_ocr/0099_samples.png
#  extracting: data_ocr/0100_samples.png
#  extracting: data_ocr/0101_samples.png
#  extracting: data_ocr/0102_samples.png
#  extracting: data_ocr/0103_samples.png
#  extracting: data_ocr/0104_samples.png
#  extracting: data_ocr/0105_samples.png
#  extracting: data_ocr/0106_samples.png
#  extracting: data_ocr/0107_samples.png
#  extracting: data_ocr/0108_samples.png
#  extracting: data_ocr/0109_samples.png
#  extracting: data_ocr/0110_samples.png
#  extracting: data_ocr/0111_samples.png
#  extracting: data_ocr/0112_samples.png
#  extracting: data_ocr/0113_samples.png
#  extracting: data_ocr/0114_samples.png
#  extracting: data_ocr/0115_samples.png
#  extracting: data_ocr/0116_samples.png
#   inflating: data_ocr/0117_samples.png
#   inflating: data_ocr/0118_samples.png
#  extracting: data_ocr/0119_samples.png
#   inflating: data_ocr/0120_samples.png
#  extracting: data_ocr/0121_samples.png
#  extracting: data_ocr/0122_samples.png
#   inflating: data_ocr/0123_samples.png
#  extracting: data_ocr/0124_samples.png
#  extracting: data_ocr/0125_samples.png
#  extracting: data_ocr/0126_samples.png
#  extracting: data_ocr/0127_samples.png
#   inflating: data_ocr/0128_samples.png
#  extracting: data_ocr/0129_samples.png
#  extracting: data_ocr/0130_samples.png
#  extracting: data_ocr/0131_samples.png
#  extracting: data_ocr/0132_samples.png
#  extracting: data_ocr/0133_samples.png
#  extracting: data_ocr/0134_samples.png
#  extracting: data_ocr/0135_samples.png
#  extracting: data_ocr/0136_samples.png
#  extracting: data_ocr/0137_samples.png
#  extracting: data_ocr/0138_samples.png
#  extracting: data_ocr/0139_samples.png
#  extracting: data_ocr/0140_samples.png
#   inflating: data_ocr/0141_samples.png
#  extracting: data_ocr/0142_samples.png
#   inflating: data_ocr/0143_samples.png
#  extracting: data_ocr/0144_samples.png
#  extracting: data_ocr/0145_samples.png
#  extracting: data_ocr/0146_samples.png
#  extracting: data_ocr/0147_samples.png
#   inflating: data_ocr/0148_samples.png
#  extracting: data_ocr/0149_samples.png
#  extracting: data_ocr/0150_samples.png
#  extracting: data_ocr/0151_samples.png
#  extracting: data_ocr/0152_samples.png
#  extracting: data_ocr/0153_samples.png
#   inflating: data_ocr/0154_samples.png
#  extracting: data_ocr/0155_samples.png
#   inflating: data_ocr/0156_samples.png
#  extracting: data_ocr/0157_samples.png
#  extracting: data_ocr/0158_samples.png
#   inflating: data_ocr/0159_samples.png
#   inflating: data_ocr/0160_samples.png
#  extracting: data_ocr/0161_samples.png
#   inflating: data_ocr/0162_samples.png
#  extracting: data_ocr/0163_samples.png
#  extracting: data_ocr/0164_samples.png
#  extracting: data_ocr/0165_samples.png
#   inflating: data_ocr/0166_samples.png
#  extracting: data_ocr/0167_samples.png
#  extracting: data_ocr/0168_samples.png
#  extracting: data_ocr/0169_samples.png
#  extracting: data_ocr/0170_samples.png
#  extracting: data_ocr/0171_samples.png
#   inflating: data_ocr/0172_samples.png
#  extracting: data_ocr/0173_samples.png
#  extracting: data_ocr/0174_samples.png
#  extracting: data_ocr/0175_samples.png
#  extracting: data_ocr/0176_samples.png
#  extracting: data_ocr/0177_samples.png
#  extracting: data_ocr/0178_samples.png
#  extracting: data_ocr/0179_samples.png
#  extracting: data_ocr/0180_samples.png
#  extracting: data_ocr/0181_samples.png
#  extracting: data_ocr/0182_samples.png
#  extracting: data_ocr/0183_samples.png
#  extracting: data_ocr/0184_samples.png
#  extracting: data_ocr/0185_samples.png
#  extracting: data_ocr/0186_samples.png
#  extracting: data_ocr/0187_samples.png
#  extracting: data_ocr/0188_samples.png
#  extracting: data_ocr/0189_samples.png
#  extracting: data_ocr/0190_samples.png
#  extracting: data_ocr/0191_samples.png
#   inflating: data_ocr/0192_samples.png
#  extracting: data_ocr/0193_samples.png
#  extracting: data_ocr/0194_samples.png
#  extracting: data_ocr/0195_samples.png
#  extracting: data_ocr/0196_samples.png
#  extracting: data_ocr/0197_samples.png
#  extracting: data_ocr/0198_samples.png
#  extracting: data_ocr/0199_samples.png
#  extracting: data_ocr/0200_samples.png
#   inflating: data_ocr/0201_samples.png
#  extracting: data_ocr/0202_samples.png
#  extracting: data_ocr/0203_samples.png
#  extracting: data_ocr/0204_samples.png
#  extracting: data_ocr/0205_samples.png
#  extracting: data_ocr/0206_samples.png
#  extracting: data_ocr/0207_samples.png
#  extracting: data_ocr/0208_samples.png
#  extracting: data_ocr/0209_samples.png
#  extracting: data_ocr/0210_samples.png
#  extracting: data_ocr/0211_samples.png
#  extracting: data_ocr/0212_samples.png
#  extracting: data_ocr/0213_samples.png
#  extracting: data_ocr/0214_samples.png
#   inflating: data_ocr/0215_samples.png
#  extracting: data_ocr/0216_samples.png
#   inflating: data_ocr/0217_samples.png
#  extracting: data_ocr/0218_samples.png
#  extracting: data_ocr/0219_samples.png
#  extracting: data_ocr/0220_samples.png
#  extracting: data_ocr/0221_samples.png
#  extracting: data_ocr/0222_samples.png
#  extracting: data_ocr/0223_samples.png
#  extracting: data_ocr/0224_samples.png
#   inflating: data_ocr/0225_samples.png
#  extracting: data_ocr/0226_samples.png
#  extracting: data_ocr/0227_samples.png
#  extracting: data_ocr/0228_samples.png
#  extracting: data_ocr/0229_samples.png
#  extracting: data_ocr/0230_samples.png
#  extracting: data_ocr/0231_samples.png
#  extracting: data_ocr/0232_samples.png
#  extracting: data_ocr/0233_samples.png
#  extracting: data_ocr/0234_samples.png
#  extracting: data_ocr/0235_samples.png
#  extracting: data_ocr/0236_samples.png
#  extracting: data_ocr/0237_samples.png
#  extracting: data_ocr/0238_samples.png
#  extracting: data_ocr/0239_samples.png
#  extracting: data_ocr/0240_samples.png
#  extracting: data_ocr/0241_samples.png
#  extracting: data_ocr/0242_samples.png
#  extracting: data_ocr/0243_samples.png
#  extracting: data_ocr/0244_samples.png
#  extracting: data_ocr/0245_samples.png
#  extracting: data_ocr/0246_samples.png
#  extracting: data_ocr/0247_samples.png
#  extracting: data_ocr/0248_samples.png
#  extracting: data_ocr/0249_samples.png
#  extracting: data_ocr/0250_samples.png
#  extracting: data_ocr/0251_samples.png
#  extracting: data_ocr/0252_samples.png
#  extracting: data_ocr/0253_samples.png
#   inflating: data_ocr/0254_samples.png
#  extracting: data_ocr/0255_samples.png
#  extracting: data_ocr/0256_samples.png
#  extracting: data_ocr/0257_samples.png
#   inflating: data_ocr/0258_samples.png
#  extracting: data_ocr/0259_samples.png
#  extracting: data_ocr/0260_samples.png
#  extracting: data_ocr/0261_samples.png
#  extracting: data_ocr/0262_samples.png
#  extracting: data_ocr/0263_samples.png
#  extracting: data_ocr/0264_samples.png
#  extracting: data_ocr/0265_samples.png
#  extracting: data_ocr/0266_samples.png
#  extracting: data_ocr/0267_samples.png
#  extracting: data_ocr/0268_samples.png
#  extracting: data_ocr/0269_samples.png
#  extracting: data_ocr/0270_samples.png
#  extracting: data_ocr/0271_samples.png
#  extracting: data_ocr/0272_samples.png
#  extracting: data_ocr/0273_samples.png
#  extracting: data_ocr/0274_samples.png
#  extracting: data_ocr/0275_samples.png
#   inflating: data_ocr/0276_samples.png
#  extracting: data_ocr/0277_samples.png
#  extracting: data_ocr/0278_samples.png
#  extracting: data_ocr/0279_samples.png
#   inflating: data_ocr/0280_samples.png
#  extracting: data_ocr/0281_samples.png
#  extracting: data_ocr/0282_samples.png
#  extracting: data_ocr/0283_samples.png
#  extracting: data_ocr/0284_samples.png
#  extracting: data_ocr/0285_samples.png
#  extracting: data_ocr/0286_samples.png
#  extracting: data_ocr/0287_samples.png
#  extracting: data_ocr/0288_samples.png
#  extracting: data_ocr/0289_samples.png
#   inflating: data_ocr/0290_samples.png
#  extracting: data_ocr/0291_samples.png
#  extracting: data_ocr/0292_samples.png
#  extracting: data_ocr/0293_samples.png
#  extracting: data_ocr/0294_samples.png
#  extracting: data_ocr/0295_samples.png
#  extracting: data_ocr/0296_samples.png
#  extracting: data_ocr/0297_samples.png
#  extracting: data_ocr/0298_samples.png
#  extracting: data_ocr/0299_samples.png
#  extracting: data_ocr/0300_samples.png
#  extracting: data_ocr/0301_samples.png
#  extracting: data_ocr/0302_samples.png
#  extracting: data_ocr/0303_samples.png
#   inflating: data_ocr/0304_samples.png
#  extracting: data_ocr/0305_samples.png
#  extracting: data_ocr/0306_samples.png
#  extracting: data_ocr/0307_samples.png
#  extracting: data_ocr/0308_samples.png
#  extracting: data_ocr/0309_samples.png
#  extracting: data_ocr/0310_samples.png
#  extracting: data_ocr/0311_samples.png
#  extracting: data_ocr/0312_samples.png
#  extracting: data_ocr/0313_samples.png
#  extracting: data_ocr/0314_samples.png
#  extracting: data_ocr/0315_samples.png
#  extracting: data_ocr/0316_samples.png
#  extracting: data_ocr/0317_samples.png
#  extracting: data_ocr/0318_samples.png
#  extracting: data_ocr/0319_samples.png
#  extracting: data_ocr/0320_samples.png
#  extracting: data_ocr/0321_samples.png
#  extracting: data_ocr/0322_samples.png
#   inflating: data_ocr/0323_samples.png
#  extracting: data_ocr/0324_samples.png
#  extracting: data_ocr/0325_samples.png
#  extracting: data_ocr/0326_samples.png
#  extracting: data_ocr/0327_samples.png
#  extracting: data_ocr/0328_samples.png
#  extracting: data_ocr/0329_samples.png
#  extracting: data_ocr/0330_samples.png
#  extracting: data_ocr/0331_samples.png
#  extracting: data_ocr/0332_samples.png
#  extracting: data_ocr/0333_samples.png
#  extracting: data_ocr/0334_samples.png
#  extracting: data_ocr/0335_samples.png
#  extracting: data_ocr/0336_samples.png
#  extracting: data_ocr/0337_samples.png
#  extracting: data_ocr/0338_samples.png
#  extracting: data_ocr/0339_samples.png
#  extracting: data_ocr/0340_samples.png
#  extracting: data_ocr/0341_samples.png
#  extracting: data_ocr/0342_samples.png
#  extracting: data_ocr/0343_samples.png
#  extracting: data_ocr/0344_samples.png
#  extracting: data_ocr/0345_samples.png
#  extracting: data_ocr/0346_samples.png
#  extracting: data_ocr/0347_samples.png
#  extracting: data_ocr/0348_samples.png
#  extracting: data_ocr/0349_samples.png
#   inflating: data_ocr/0350_samples.png
#  extracting: data_ocr/0351_samples.png
#  extracting: data_ocr/0352_samples.png
#  extracting: data_ocr/0353_samples.png
#  extracting: data_ocr/0354_samples.png
#  extracting: data_ocr/0355_samples.png
#  extracting: data_ocr/0356_samples.png
#  extracting: data_ocr/0357_samples.png
#   inflating: data_ocr/0358_samples.png
#  extracting: data_ocr/0359_samples.png
#  extracting: data_ocr/0360_samples.png
#  extracting: data_ocr/0361_samples.png
#  extracting: data_ocr/0362_samples.png
#  extracting: data_ocr/0363_samples.png
#  extracting: data_ocr/0364_samples.png
#   inflating: data_ocr/0365_samples.png
#   inflating: data_ocr/0366_samples.png
#   inflating: data_ocr/0367_samples.png
#  extracting: data_ocr/0368_samples.png
#  extracting: data_ocr/0369_samples.png
#  extracting: data_ocr/0370_samples.png
#  extracting: data_ocr/0371_samples.png
#  extracting: data_ocr/0372_samples.png
#  extracting: data_ocr/0373_samples.png
#  extracting: data_ocr/0374_samples.png
#  extracting: data_ocr/0375_samples.png
#  extracting: data_ocr/0376_samples.png
#  extracting: data_ocr/0377_samples.png
#  extracting: data_ocr/0378_samples.png
#  extracting: data_ocr/0379_samples.png
#  extracting: data_ocr/0380_samples.png
#  extracting: data_ocr/0381_samples.png
#  extracting: data_ocr/0382_samples.png
#   inflating: data_ocr/0383_samples.png
#   inflating: data_ocr/0384_samples.png
#  extracting: data_ocr/0385_samples.png
#  extracting: data_ocr/0386_samples.png
#  extracting: data_ocr/0387_samples.png
#  extracting: data_ocr/0388_samples.png
#   inflating: data_ocr/0389_samples.png
#  extracting: data_ocr/0390_samples.png
#  extracting: data_ocr/0391_samples.png
#  extracting: data_ocr/0392_samples.png
#  extracting: data_ocr/0393_samples.png
#  extracting: data_ocr/0394_samples.png
#   inflating: data_ocr/0395_samples.png
#  extracting: data_ocr/0396_samples.png
#   inflating: data_ocr/0397_samples.png
#  extracting: data_ocr/0398_samples.png
#  extracting: data_ocr/0399_samples.png
#  extracting: data_ocr/0400_samples.png
#  extracting: data_ocr/0401_samples.png
#  extracting: data_ocr/0402_samples.png
#  extracting: data_ocr/0403_samples.png
#  extracting: data_ocr/0404_samples.png
#  extracting: data_ocr/0405_samples.png
#  extracting: data_ocr/0406_samples.png
#  extracting: data_ocr/0407_samples.png
#  extracting: data_ocr/0408_samples.png
#  extracting: data_ocr/0409_samples.png
#   inflating: data_ocr/0410_samples.png
#  extracting: data_ocr/0411_samples.png
#  extracting: data_ocr/0412_samples.png
#  extracting: data_ocr/0413_samples.png
#  extracting: data_ocr/0414_samples.png
#  extracting: data_ocr/0415_samples.png
#  extracting: data_ocr/0416_samples.png
#  extracting: data_ocr/0417_samples.png
#  extracting: data_ocr/0418_samples.png
#  extracting: data_ocr/0419_samples.png
#  extracting: data_ocr/0420_samples.png
#  extracting: data_ocr/0421_samples.png
#  extracting: data_ocr/0422_samples.png
#  extracting: data_ocr/0423_samples.png
#  extracting: data_ocr/0424_samples.png
#  extracting: data_ocr/0425_samples.png
#  extracting: data_ocr/0426_samples.png
#  extracting: data_ocr/0427_samples.png
#  extracting: data_ocr/0428_samples.png
#  extracting: data_ocr/0429_samples.png
#  extracting: data_ocr/0430_samples.png
#  extracting: data_ocr/0431_samples.png
#  extracting: data_ocr/0432_samples.png
#  extracting: data_ocr/0433_samples.png
#  extracting: data_ocr/0434_samples.png
#  extracting: data_ocr/0435_samples.png
#  extracting: data_ocr/0436_samples.png
#  extracting: data_ocr/0437_samples.png
#  extracting: data_ocr/0438_samples.png
#  extracting: data_ocr/0439_samples.png
#  extracting: data_ocr/0440_samples.png
#  extracting: data_ocr/0441_samples.png
#   inflating: data_ocr/0442_samples.png
#  extracting: data_ocr/0443_samples.png
#  extracting: data_ocr/0444_samples.png
#  extracting: data_ocr/0445_samples.png
#  extracting: data_ocr/0446_samples.png
#  extracting: data_ocr/0447_samples.png
#  extracting: data_ocr/0448_samples.png
#  extracting: data_ocr/0449_samples.png
#  extracting: data_ocr/0450_samples.png
#  extracting: data_ocr/0451_samples.png
#  extracting: data_ocr/0452_samples.png
#  extracting: data_ocr/0453_samples.png
#  extracting: data_ocr/0454_samples.png
#  extracting: data_ocr/0455_samples.png
#  extracting: data_ocr/0456_samples.png
#  extracting: data_ocr/0457_samples.png
#  extracting: data_ocr/0458_samples.png
#  extracting: data_ocr/0459_samples.png
#   inflating: data_ocr/0460_samples.png
#  extracting: data_ocr/0461_samples.png
#  extracting: data_ocr/0462_samples.png
#  extracting: data_ocr/0463_samples.png
#  extracting: data_ocr/0464_samples.png
#  extracting: data_ocr/0465_samples.png
#  extracting: data_ocr/0466_samples.png
#  extracting: data_ocr/0467_samples.png
#   inflating: data_ocr/0468_samples.png
#  extracting: data_ocr/0469_samples.png
#  extracting: data_ocr/0470_samples.png
#  extracting: data_ocr/0471_samples.png
#   inflating: data_ocr/0472_samples.png
#  extracting: data_ocr/0473_samples.png
#  extracting: data_ocr/0474_samples.png
#  extracting: data_ocr/0475_samples.png
#  extracting: data_ocr/0476_samples.png
#  extracting: data_ocr/0477_samples.png
#  extracting: data_ocr/0478_samples.png
#  extracting: data_ocr/0479_samples.png
#  extracting: data_ocr/0480_samples.png
#  extracting: data_ocr/0481_samples.png
#  extracting: data_ocr/0482_samples.png
#  extracting: data_ocr/0483_samples.png
#   inflating: data_ocr/0484_samples.png
#  extracting: data_ocr/0485_samples.png
#  extracting: data_ocr/0486_samples.png
#  extracting: data_ocr/0487_samples.png
#  extracting: data_ocr/0488_samples.png
#  extracting: data_ocr/0489_samples.png
#  extracting: data_ocr/0490_samples.png
#  extracting: data_ocr/0491_samples.png
#  extracting: data_ocr/0492_samples.png
#  extracting: data_ocr/0493_samples.png
#  extracting: data_ocr/0494_samples.png
#  extracting: data_ocr/0495_samples.png
#   inflating: data_ocr/0496_samples.png
#  extracting: data_ocr/0497_samples.png
#  extracting: data_ocr/0498_samples.png
#  extracting: data_ocr/0499_samples.png
#  extracting: data_ocr/0500_samples.png
#   inflating: data_ocr/0501_samples.png
#  extracting: data_ocr/0502_samples.png
#  extracting: data_ocr/0503_samples.png
#  extracting: data_ocr/0504_samples.png
#  extracting: data_ocr/0505_samples.png
#   inflating: data_ocr/0506_samples.png
#  extracting: data_ocr/0507_samples.png
#  extracting: data_ocr/0508_samples.png
#  extracting: data_ocr/0509_samples.png
#  extracting: data_ocr/0510_samples.png
#  extracting: data_ocr/0511_samples.png
#  extracting: data_ocr/0512_samples.png
#  extracting: data_ocr/0513_samples.png
#  extracting: data_ocr/0514_samples.png
#  extracting: data_ocr/0515_samples.png
#  extracting: data_ocr/0516_samples.png
#  extracting: data_ocr/0517_samples.png
#  extracting: data_ocr/0518_samples.png
#  extracting: data_ocr/0519_samples.png
#  extracting: data_ocr/0520_samples.png
#  extracting: data_ocr/0521_samples.png
#  extracting: data_ocr/0522_samples.png
#  extracting: data_ocr/0523_samples.png
#   inflating: data_ocr/0524_samples.png
#  extracting: data_ocr/0525_samples.png
#   inflating: data_ocr/0526_samples.png
#  extracting: data_ocr/0527_samples.png
#   inflating: data_ocr/0528_samples.png
#  extracting: data_ocr/0529_samples.png
#  extracting: data_ocr/0530_samples.png
#  extracting: data_ocr/0531_samples.png
#  extracting: data_ocr/0532_samples.png
#  extracting: data_ocr/0533_samples.png
#   inflating: data_ocr/0534_samples.png
#  extracting: data_ocr/0535_samples.png
#  extracting: data_ocr/0536_samples.png
#   inflating: data_ocr/0537_samples.png
#  extracting: data_ocr/0538_samples.png
#  extracting: data_ocr/0539_samples.png
#   inflating: data_ocr/0540_samples.png
#  extracting: data_ocr/0541_samples.png
#  extracting: data_ocr/0542_samples.png
#  extracting: data_ocr/0543_samples.png
#  extracting: data_ocr/0544_samples.png
#  extracting: data_ocr/0545_samples.png
#  extracting: data_ocr/0546_samples.png
#  extracting: data_ocr/0547_samples.png
#  extracting: data_ocr/0548_samples.png
#   inflating: data_ocr/0549_samples.png
#  extracting: data_ocr/0550_samples.png
#  extracting: data_ocr/0551_samples.png
#  extracting: data_ocr/0552_samples.png
#  extracting: data_ocr/0553_samples.png
#  extracting: data_ocr/0554_samples.png
#  extracting: data_ocr/0555_samples.png
#  extracting: data_ocr/0556_samples.png
#   inflating: data_ocr/0557_samples.png
#  extracting: data_ocr/0558_samples.png
#   inflating: data_ocr/0559_samples.png
#  extracting: data_ocr/0560_samples.png
#  extracting: data_ocr/0561_samples.png
#  extracting: data_ocr/0562_samples.png
#  extracting: data_ocr/0563_samples.png
#   inflating: data_ocr/0564_samples.png
#  extracting: data_ocr/0565_samples.png
#  extracting: data_ocr/0566_samples.png
#  extracting: data_ocr/0567_samples.png
#  extracting: data_ocr/0568_samples.png
#  extracting: data_ocr/0569_samples.png
#  extracting: data_ocr/0570_samples.png
#   inflating: data_ocr/0571_samples.png
#  extracting: data_ocr/0572_samples.png
#  extracting: data_ocr/0573_samples.png
#  extracting: data_ocr/0574_samples.png
#  extracting: data_ocr/0575_samples.png
#  extracting: data_ocr/0576_samples.png
#   inflating: data_ocr/0577_samples.png
#  extracting: data_ocr/0578_samples.png
#   inflating: data_ocr/0579_samples.png
#   inflating: data_ocr/0580_samples.png
#  extracting: data_ocr/0581_samples.png
#  extracting: data_ocr/0582_samples.png
#  extracting: data_ocr/0583_samples.png
#  extracting: data_ocr/0584_samples.png
#  extracting: data_ocr/0585_samples.png
#  extracting: data_ocr/0586_samples.png
#  extracting: data_ocr/0587_samples.png
#  extracting: data_ocr/0588_samples.png
#  extracting: data_ocr/0589_samples.png
#   inflating: data_ocr/0590_samples.png
#  extracting: data_ocr/0591_samples.png
#   inflating: data_ocr/0592_samples.png
#  extracting: data_ocr/0593_samples.png
#  extracting: data_ocr/0594_samples.png
#  extracting: data_ocr/0595_samples.png
#  extracting: data_ocr/0596_samples.png
#  extracting: data_ocr/0597_samples.png
#  extracting: data_ocr/0598_samples.png
#  extracting: data_ocr/0599_samples.png
#  extracting: data_ocr/0600_samples.png
#  extracting: data_ocr/0601_samples.png
#  extracting: data_ocr/0602_samples.png
#  extracting: data_ocr/0603_samples.png
#  extracting: data_ocr/0604_samples.png
#  extracting: data_ocr/0605_samples.png
#  extracting: data_ocr/0606_samples.png
#  extracting: data_ocr/0607_samples.png
#  extracting: data_ocr/0608_samples.png
#  extracting: data_ocr/0609_samples.png
#  extracting: data_ocr/0610_samples.png
#   inflating: data_ocr/0611_samples.png
#   inflating: data_ocr/0612_samples.png
#  extracting: data_ocr/0613_samples.png
#   inflating: data_ocr/0614_samples.png
#  extracting: data_ocr/0615_samples.png
#  extracting: data_ocr/0616_samples.png
#  extracting: data_ocr/0617_samples.png
#  extracting: data_ocr/0618_samples.png
#  extracting: data_ocr/0619_samples.png
#  extracting: data_ocr/0620_samples.png
#  extracting: data_ocr/0621_samples.png
#  extracting: data_ocr/0622_samples.png
#  extracting: data_ocr/0623_samples.png
#  extracting: data_ocr/0624_samples.png
#  extracting: data_ocr/0625_samples.png
#   inflating: data_ocr/0626_samples.png
#  extracting: data_ocr/0627_samples.png
#  extracting: data_ocr/0628_samples.png
#  extracting: data_ocr/0629_samples.png
#  extracting: data_ocr/0630_samples.png
#  extracting: data_ocr/0631_samples.png
#  extracting: data_ocr/0632_samples.png
#  extracting: data_ocr/0633_samples.png
#  extracting: data_ocr/0634_samples.png
#  extracting: data_ocr/0635_samples.png
#  extracting: data_ocr/0636_samples.png
#  extracting: data_ocr/0637_samples.png
#  extracting: data_ocr/0638_samples.png
#  extracting: data_ocr/0639_samples.png
#  extracting: data_ocr/0640_samples.png
#   inflating: data_ocr/0641_samples.png
#  extracting: data_ocr/0642_samples.png
#  extracting: data_ocr/0643_samples.png
#  extracting: data_ocr/0644_samples.png
#  extracting: data_ocr/0645_samples.png
#   inflating: data_ocr/0646_samples.png
#  extracting: data_ocr/0647_samples.png
#  extracting: data_ocr/0648_samples.png
#  extracting: data_ocr/0649_samples.png
#  extracting: data_ocr/0650_samples.png
#  extracting: data_ocr/0651_samples.png
#  extracting: data_ocr/0652_samples.png
#  extracting: data_ocr/0653_samples.png
#   inflating: data_ocr/0654_samples.png
#  extracting: data_ocr/0655_samples.png
#  extracting: data_ocr/0656_samples.png
#  extracting: data_ocr/0657_samples.png
#  extracting: data_ocr/0658_samples.png
#   inflating: data_ocr/0659_samples.png
#  extracting: data_ocr/0660_samples.png
#  extracting: data_ocr/0661_samples.png
#  extracting: data_ocr/0662_samples.png
#  extracting: data_ocr/0663_samples.png
#  extracting: data_ocr/0664_samples.png
#  extracting: data_ocr/0665_samples.png
#  extracting: data_ocr/0666_samples.png
#  extracting: data_ocr/0667_samples.png
#  extracting: data_ocr/0668_samples.png
#  extracting: data_ocr/0669_samples.png
#  extracting: data_ocr/0670_samples.png
#  extracting: data_ocr/0671_samples.png
#   inflating: data_ocr/0672_samples.png
#  extracting: data_ocr/0673_samples.png
#  extracting: data_ocr/0674_samples.png
#  extracting: data_ocr/0675_samples.png
#   inflating: data_ocr/0676_samples.png
#  extracting: data_ocr/0677_samples.png
#   inflating: data_ocr/0678_samples.png
#  extracting: data_ocr/0679_samples.png
#  extracting: data_ocr/0680_samples.png
#  extracting: data_ocr/0681_samples.png
#  extracting: data_ocr/0682_samples.png
#  extracting: data_ocr/0683_samples.png
#  extracting: data_ocr/0684_samples.png
#  extracting: data_ocr/0685_samples.png
#  extracting: data_ocr/0686_samples.png
#  extracting: data_ocr/0687_samples.png
#  extracting: data_ocr/0688_samples.png
#  extracting: data_ocr/0689_samples.png
#  extracting: data_ocr/0690_samples.png
#  extracting: data_ocr/0691_samples.png
#  extracting: data_ocr/0692_samples.png
#  extracting: data_ocr/0693_samples.png
#  extracting: data_ocr/0694_samples.png
#  extracting: data_ocr/0695_samples.png
#  extracting: data_ocr/0696_samples.png
#  extracting: data_ocr/0697_samples.png
#  extracting: data_ocr/0698_samples.png
#  extracting: data_ocr/0699_samples.png
#  extracting: data_ocr/0700_samples.png
#  extracting: data_ocr/0701_samples.png
#  extracting: data_ocr/0702_samples.png
#  extracting: data_ocr/0703_samples.png
#  extracting: data_ocr/0704_samples.png
#  extracting: data_ocr/0705_samples.png
#  extracting: data_ocr/0706_samples.png
#  extracting: data_ocr/0707_samples.png
#  extracting: data_ocr/0708_samples.png
#  extracting: data_ocr/0709_samples.png
#  extracting: data_ocr/0710_samples.png
#  extracting: data_ocr/0711_samples.png
#  extracting: data_ocr/0712_samples.png
#  extracting: data_ocr/0713_samples.png
#  extracting: data_ocr/0714_samples.png
#  extracting: data_ocr/0715_samples.png
#  extracting: data_ocr/0716_samples.png
#  extracting: data_ocr/0717_samples.png
#  extracting: data_ocr/0718_samples.png
#   inflating: data_ocr/0719_samples.png
#  extracting: data_ocr/0720_samples.png
#  extracting: data_ocr/0721_samples.png
#  extracting: data_ocr/0722_samples.png
#  extracting: data_ocr/0723_samples.png
#   inflating: data_ocr/0724_samples.png
#  extracting: data_ocr/0725_samples.png
#  extracting: data_ocr/0726_samples.png
#  extracting: data_ocr/0727_samples.png
#  extracting: data_ocr/0728_samples.png
#  extracting: data_ocr/0729_samples.png
#  extracting: data_ocr/0730_samples.png
#  extracting: data_ocr/0731_samples.png
#  extracting: data_ocr/0732_samples.png
#  extracting: data_ocr/0733_samples.png
#  extracting: data_ocr/0734_samples.png
#  extracting: data_ocr/0735_samples.png
#  extracting: data_ocr/0736_samples.png
#  extracting: data_ocr/0737_samples.png
#  extracting: data_ocr/0738_samples.png
#  extracting: data_ocr/0739_samples.png
#  extracting: data_ocr/0740_samples.png
#  extracting: data_ocr/0741_samples.png
#  extracting: data_ocr/0742_samples.png
#  extracting: data_ocr/0743_samples.png
#  extracting: data_ocr/0744_samples.png
#  extracting: data_ocr/0745_samples.png
#   inflating: data_ocr/0746_samples.png
#  extracting: data_ocr/0747_samples.png
#  extracting: data_ocr/0748_samples.png
#   inflating: data_ocr/0749_samples.png
#  extracting: data_ocr/0750_samples.png
#  extracting: data_ocr/0751_samples.png
#   inflating: data_ocr/0752_samples.png
#  extracting: data_ocr/0753_samples.png
#  extracting: data_ocr/0754_samples.png
#  extracting: data_ocr/0755_samples.png
#  extracting: data_ocr/0756_samples.png
#   inflating: data_ocr/0757_samples.png
#  extracting: data_ocr/0758_samples.png
#   inflating: data_ocr/0759_samples.png
#  extracting: data_ocr/0760_samples.png
#   inflating: data_ocr/0761_samples.png
#  extracting: data_ocr/0762_samples.png
#  extracting: data_ocr/0763_samples.png
#  extracting: data_ocr/0764_samples.png
#   inflating: data_ocr/0765_samples.png
#  extracting: data_ocr/0766_samples.png
#  extracting: data_ocr/0767_samples.png
#  extracting: data_ocr/0768_samples.png
#  extracting: data_ocr/0769_samples.png
#  extracting: data_ocr/0770_samples.png
#  extracting: data_ocr/0771_samples.png
#  extracting: data_ocr/0772_samples.png
#  extracting: data_ocr/0773_samples.png
#  extracting: data_ocr/0774_samples.png
#  extracting: data_ocr/0775_samples.png
#  extracting: data_ocr/0776_samples.png
#  extracting: data_ocr/0777_samples.png
#   inflating: data_ocr/0778_samples.png
#  extracting: data_ocr/0779_samples.png
#  extracting: data_ocr/0780_samples.png
#  extracting: data_ocr/0781_samples.png
#  extracting: data_ocr/0782_samples.png
#  extracting: data_ocr/0783_samples.png
#  extracting: data_ocr/0784_samples.png
#  extracting: data_ocr/0785_samples.png
#   inflating: data_ocr/0786_samples.png
#  extracting: data_ocr/0787_samples.png
#  extracting: data_ocr/0788_samples.png
#  extracting: data_ocr/0789_samples.png
#  extracting: data_ocr/0790_samples.png
#  extracting: data_ocr/0791_samples.png
#  extracting: data_ocr/0792_samples.png
#  extracting: data_ocr/0793_samples.png
#  extracting: data_ocr/0794_samples.png
#  extracting: data_ocr/0795_samples.png
#  extracting: data_ocr/0796_samples.png
#  extracting: data_ocr/0797_samples.png
#  extracting: data_ocr/0798_samples.png
#  extracting: data_ocr/0799_samples.png
#  extracting: data_ocr/0800_samples.png
#  extracting: data_ocr/0801_samples.png
#  extracting: data_ocr/0802_samples.png
#  extracting: data_ocr/0803_samples.png
#  extracting: data_ocr/0804_samples.png
#  extracting: data_ocr/0805_samples.png
#  extracting: data_ocr/0806_samples.png
#  extracting: data_ocr/0807_samples.png
#  extracting: data_ocr/0808_samples.png
#  extracting: data_ocr/0809_samples.png
#  extracting: data_ocr/0810_samples.png
#  extracting: data_ocr/0811_samples.png
#  extracting: data_ocr/0812_samples.png
#  extracting: data_ocr/0813_samples.png
#  extracting: data_ocr/0814_samples.png
#   inflating: data_ocr/0815_samples.png
#  extracting: data_ocr/0816_samples.png
#  extracting: data_ocr/0817_samples.png
#  extracting: data_ocr/0818_samples.png
#  extracting: data_ocr/0819_samples.png
#  extracting: data_ocr/0820_samples.png
#  extracting: data_ocr/0821_samples.png
#  extracting: data_ocr/0822_samples.png
#  extracting: data_ocr/0823_samples.png
#  extracting: data_ocr/0824_samples.png
#  extracting: data_ocr/0825_samples.png
#  extracting: data_ocr/0826_samples.png
#  extracting: data_ocr/0827_samples.png
#  extracting: data_ocr/0828_samples.png
#   inflating: data_ocr/0829_samples.png
#  extracting: data_ocr/0830_samples.png
#   inflating: data_ocr/0831_samples.png
#  extracting: data_ocr/0832_samples.png
#  extracting: data_ocr/0833_samples.png
#  extracting: data_ocr/0834_samples.png
#  extracting: data_ocr/0835_samples.png
#  extracting: data_ocr/0836_samples.png
#  extracting: data_ocr/0837_samples.png
#  extracting: data_ocr/0838_samples.png
#  extracting: data_ocr/0839_samples.png
#  extracting: data_ocr/0840_samples.png
#  extracting: data_ocr/0841_samples.png
#  extracting: data_ocr/0842_samples.png
#  extracting: data_ocr/0843_samples.png
#  extracting: data_ocr/0844_samples.png
#   inflating: data_ocr/0845_samples.png
#   inflating: data_ocr/0846_samples.png
#  extracting: data_ocr/0847_samples.png
#  extracting: data_ocr/0848_samples.png
#   inflating: data_ocr/0849_samples.png
#   inflating: data_ocr/0850_samples.png
#  extracting: data_ocr/0851_samples.png
#  extracting: data_ocr/0852_samples.png
#  extracting: data_ocr/0853_samples.png
#  extracting: data_ocr/0854_samples.png
#  extracting: data_ocr/0855_samples.png
#  extracting: data_ocr/0856_samples.png
#  extracting: data_ocr/0857_samples.png
#  extracting: data_ocr/0858_samples.png
#  extracting: data_ocr/0859_samples.png
#  extracting: data_ocr/0860_samples.png
#  extracting: data_ocr/0861_samples.png
#  extracting: data_ocr/0862_samples.png
#   inflating: data_ocr/0863_samples.png
#  extracting: data_ocr/0864_samples.png
#  extracting: data_ocr/0865_samples.png
#  extracting: data_ocr/0866_samples.png
#  extracting: data_ocr/0867_samples.png
#  extracting: data_ocr/0868_samples.png
#  extracting: data_ocr/0869_samples.png
#  extracting: data_ocr/0870_samples.png
#  extracting: data_ocr/0871_samples.png
#  extracting: data_ocr/0872_samples.png
#  extracting: data_ocr/0873_samples.png
#  extracting: data_ocr/0874_samples.png
#  extracting: data_ocr/0875_samples.png
#  extracting: data_ocr/0876_samples.png
#  extracting: data_ocr/0877_samples.png
#   inflating: data_ocr/0878_samples.png
#   inflating: data_ocr/0879_samples.png
#  extracting: data_ocr/0880_samples.png
#  extracting: data_ocr/0881_samples.png
#  extracting: data_ocr/0882_samples.png
#  extracting: data_ocr/0883_samples.png
#  extracting: data_ocr/0884_samples.png
#  extracting: data_ocr/0885_samples.png
#  extracting: data_ocr/0886_samples.png
#  extracting: data_ocr/0887_samples.png
#  extracting: data_ocr/0888_samples.png
#  extracting: data_ocr/0889_samples.png
#  extracting: data_ocr/0890_samples.png
#  extracting: data_ocr/0891_samples.png
#  extracting: data_ocr/0892_samples.png
#  extracting: data_ocr/0893_samples.png
#  extracting: data_ocr/0894_samples.png
#   inflating: data_ocr/0895_samples.png
#  extracting: data_ocr/0896_samples.png
#  extracting: data_ocr/0897_samples.png
#  extracting: data_ocr/0898_samples.png
#  extracting: data_ocr/0899_samples.png
#  extracting: data_ocr/0900_samples.png
#  extracting: data_ocr/0901_samples.png
#  extracting: data_ocr/0902_samples.png
#  extracting: data_ocr/0903_samples.png
#  extracting: data_ocr/0904_samples.png
#  extracting: data_ocr/0905_samples.png
#   inflating: data_ocr/0906_samples.png
#  extracting: data_ocr/0907_samples.png
#  extracting: data_ocr/0908_samples.png
#   inflating: data_ocr/0909_samples.png
#  extracting: data_ocr/0910_samples.png
#  extracting: data_ocr/0911_samples.png
#  extracting: data_ocr/0912_samples.png
#  extracting: data_ocr/0913_samples.png
#  extracting: data_ocr/0914_samples.png
#  extracting: data_ocr/0915_samples.png
#  extracting: data_ocr/0916_samples.png
#  extracting: data_ocr/0917_samples.png
#  extracting: data_ocr/0918_samples.png
#  extracting: data_ocr/0919_samples.png
#  extracting: data_ocr/0920_samples.png
#  extracting: data_ocr/0921_samples.png
#  extracting: data_ocr/0922_samples.png
#  extracting: data_ocr/0923_samples.png
#  extracting: data_ocr/0924_samples.png
#  extracting: data_ocr/0925_samples.png
#   inflating: data_ocr/0926_samples.png
#  extracting: data_ocr/0927_samples.png
#  extracting: data_ocr/0928_samples.png
#   inflating: data_ocr/0929_samples.png
#  extracting: data_ocr/0930_samples.png
#  extracting: data_ocr/0931_samples.png
#  extracting: data_ocr/0932_samples.png
#  extracting: data_ocr/0933_samples.png
#   inflating: data_ocr/0934_samples.png
#   inflating: data_ocr/0935_samples.png
#   inflating: data_ocr/0936_samples.png
#  extracting: data_ocr/0937_samples.png
#  extracting: data_ocr/0938_samples.png
#  extracting: data_ocr/0939_samples.png
#   inflating: data_ocr/0940_samples.png
#  extracting: data_ocr/0941_samples.png
#  extracting: data_ocr/0942_samples.png
#  extracting: data_ocr/0943_samples.png
#  extracting: data_ocr/0944_samples.png
#  extracting: data_ocr/0945_samples.png
#  extracting: data_ocr/0946_samples.png
#  extracting: data_ocr/0947_samples.png
#  extracting: data_ocr/0948_samples.png
#  extracting: data_ocr/0949_samples.png
#   inflating: data_ocr/0950_samples.png
#  extracting: data_ocr/0951_samples.png
#  extracting: data_ocr/0952_samples.png
#   inflating: data_ocr/0953_samples.png
#  extracting: data_ocr/0954_samples.png
#  extracting: data_ocr/0955_samples.png
#  extracting: data_ocr/0956_samples.png
#  extracting: data_ocr/0957_samples.png
#  extracting: data_ocr/0958_samples.png
#  extracting: data_ocr/0959_samples.png
#  extracting: data_ocr/0960_samples.png
#  extracting: data_ocr/0961_samples.png
#  extracting: data_ocr/0962_samples.png
#  extracting: data_ocr/0963_samples.png
#  extracting: data_ocr/0964_samples.png
#  extracting: data_ocr/0965_samples.png
#  extracting: data_ocr/0966_samples.png
#  extracting: data_ocr/0967_samples.png
#  extracting: data_ocr/0968_samples.png
#  extracting: data_ocr/0969_samples.png
#  extracting: data_ocr/0970_samples.png
#  extracting: data_ocr/0971_samples.png
#  extracting: data_ocr/0972_samples.png
#  extracting: data_ocr/0973_samples.png
#  extracting: data_ocr/0974_samples.png
#  extracting: data_ocr/0975_samples.png
#  extracting: data_ocr/0976_samples.png
#  extracting: data_ocr/0977_samples.png
#  extracting: data_ocr/0978_samples.png
#  extracting: data_ocr/0979_samples.png
#  extracting: data_ocr/0980_samples.png
#  extracting: data_ocr/0981_samples.png
#  extracting: data_ocr/0982_samples.png
#  extracting: data_ocr/0983_samples.png
#  extracting: data_ocr/0984_samples.png
#  extracting: data_ocr/0985_samples.png
#  extracting: data_ocr/0986_samples.png
#  extracting: data_ocr/0987_samples.png
#  extracting: data_ocr/0988_samples.png
#  extracting: data_ocr/0989_samples.png
#   inflating: data_ocr/0990_samples.png
#  extracting: data_ocr/0991_samples.png
#  extracting: data_ocr/0992_samples.png
#  extracting: data_ocr/0993_samples.png
#  extracting: data_ocr/0994_samples.png
#  extracting: data_ocr/0995_samples.png
#  extracting: data_ocr/0996_samples.png
#  extracting: data_ocr/0997_samples.png
#  extracting: data_ocr/0998_samples.png
#  extracting: data_ocr/0999_samples.png
#  extracting: data_ocr/1000_samples.png
#  extracting: data_ocr/1001_samples.png
#  extracting: data_ocr/1002_samples.png
#  extracting: data_ocr/1003_samples.png
#   inflating: data_ocr/1004_samples.png
#  extracting: data_ocr/1005_samples.png
#  extracting: data_ocr/1006_samples.png
#   inflating: data_ocr/1007_samples.png
#  extracting: data_ocr/1008_samples.png
#  extracting: data_ocr/1009_samples.png
#  extracting: data_ocr/1010_samples.png
#  extracting: data_ocr/1011_samples.png
#  extracting: data_ocr/1012_samples.png
#  extracting: data_ocr/1013_samples.png
#  extracting: data_ocr/1014_samples.png
#  extracting: data_ocr/1015_samples.png
#  extracting: data_ocr/1016_samples.png
#   inflating: data_ocr/1017_samples.png
#  extracting: data_ocr/1018_samples.png
#  extracting: data_ocr/1019_samples.png
#  extracting: data_ocr/1020_samples.png
#  extracting: data_ocr/1021_samples.png
#   inflating: data_ocr/1022_samples.png
#  extracting: data_ocr/1023_samples.png
#  extracting: data_ocr/1024_samples.png
#  extracting: data_ocr/1025_samples.png
#  extracting: data_ocr/1026_samples.png
#  extracting: data_ocr/1027_samples.png
#  extracting: data_ocr/1028_samples.png
#  extracting: data_ocr/1029_samples.png
#  extracting: data_ocr/1030_samples.png
#  extracting: data_ocr/1031_samples.png
#   inflating: data_ocr/1032_samples.png
#  extracting: data_ocr/1033_samples.png
#   inflating: data_ocr/1034_samples.png
#   inflating: data_ocr/1035_samples.png
#  extracting: data_ocr/1036_samples.png
#  extracting: data_ocr/1037_samples.png
#  extracting: data_ocr/1038_samples.png
#  extracting: data_ocr/1039_samples.png
#  extracting: data_ocr/1040_samples.png
#  extracting: data_ocr/1041_samples.png
#  extracting: data_ocr/1042_samples.png
#  extracting: data_ocr/1043_samples.png
#  extracting: data_ocr/1044_samples.png
#  extracting: data_ocr/1045_samples.png
#  extracting: data_ocr/1046_samples.png
#  extracting: data_ocr/1047_samples.png
#  extracting: data_ocr/1048_samples.png
#  extracting: data_ocr/1049_samples.png
#  extracting: data_ocr/1050_samples.png
#  extracting: data_ocr/1051_samples.png
#  extracting: data_ocr/1052_samples.png
#  extracting: data_ocr/1053_samples.png
#  extracting: data_ocr/1054_samples.png
#  extracting: data_ocr/1055_samples.png
#  extracting: data_ocr/1056_samples.png
#  extracting: data_ocr/1057_samples.png
#  extracting: data_ocr/1058_samples.png
#  extracting: data_ocr/1059_samples.png
#   inflating: data_ocr/1060_samples.png
#  extracting: data_ocr/1061_samples.png
#  extracting: data_ocr/1062_samples.png
#  extracting: data_ocr/1063_samples.png
#  extracting: data_ocr/1064_samples.png
#  extracting: data_ocr/1065_samples.png
#  extracting: data_ocr/1066_samples.png
#  extracting: data_ocr/1067_samples.png
#  extracting: data_ocr/1068_samples.png
#  extracting: data_ocr/1069_samples.png
#  extracting: data_ocr/1070_samples.png
#  extracting: data_ocr/1071_samples.png
#  extracting: data_ocr/1072_samples.png
#  extracting: data_ocr/1073_samples.png
#  extracting: data_ocr/1074_samples.png
#  extracting: data_ocr/1075_samples.png
#  extracting: data_ocr/1076_samples.png
#  extracting: data_ocr/1077_samples.png
#  extracting: data_ocr/1078_samples.png
#   inflating: data_ocr/1079_samples.png
#  extracting: data_ocr/1080_samples.png
#  extracting: data_ocr/1081_samples.png
#  extracting: data_ocr/1082_samples.png
#  extracting: data_ocr/1083_samples.png
#  extracting: data_ocr/1084_samples.png
#  extracting: data_ocr/1085_samples.png
#  extracting: data_ocr/1086_samples.png
#  extracting: data_ocr/1087_samples.png
#  extracting: data_ocr/1088_samples.png
#  extracting: data_ocr/1089_samples.png
#  extracting: data_ocr/1090_samples.png
#  extracting: data_ocr/1091_samples.png
#  extracting: data_ocr/1092_samples.png
#  extracting: data_ocr/1093_samples.png
#   inflating: data_ocr/1094_samples.png
#  extracting: data_ocr/1095_samples.png
#  extracting: data_ocr/1096_samples.png
#  extracting: data_ocr/1097_samples.png
#   inflating: data_ocr/1098_samples.png
#  extracting: data_ocr/1099_samples.png
#  extracting: data_ocr/1100_samples.png
#  extracting: data_ocr/1101_samples.png
#  extracting: data_ocr/1102_samples.png
#  extracting: data_ocr/1103_samples.png
#  extracting: data_ocr/1104_samples.png
#  extracting: data_ocr/1105_samples.png
#  extracting: data_ocr/1106_samples.png
#  extracting: data_ocr/1107_samples.png
#  extracting: data_ocr/1108_samples.png
#  extracting: data_ocr/1109_samples.png
#  extracting: data_ocr/1110_samples.png
#  extracting: data_ocr/1111_samples.png
#  extracting: data_ocr/1112_samples.png
#   inflating: data_ocr/1113_samples.png
#  extracting: data_ocr/1114_samples.png
#  extracting: data_ocr/1115_samples.png
#  extracting: data_ocr/1116_samples.png
#   inflating: data_ocr/1117_samples.png
#  extracting: data_ocr/1118_samples.png
#  extracting: data_ocr/1119_samples.png
#  extracting: data_ocr/1120_samples.png
#  extracting: data_ocr/1121_samples.png
#  extracting: data_ocr/1122_samples.png
#  extracting: data_ocr/1123_samples.png
#  extracting: data_ocr/1124_samples.png
#  extracting: data_ocr/1125_samples.png
#  extracting: data_ocr/1126_samples.png
#  extracting: data_ocr/1127_samples.png
#   inflating: data_ocr/1128_samples.png
#  extracting: data_ocr/1129_samples.png
#  extracting: data_ocr/1130_samples.png
#  extracting: data_ocr/1131_samples.png
#  extracting: data_ocr/1132_samples.png
#  extracting: data_ocr/1133_samples.png
#   inflating: data_ocr/1134_samples.png
#   inflating: data_ocr/1135_samples.png
#  extracting: data_ocr/1136_samples.png
#  extracting: data_ocr/1137_samples.png
#   inflating: data_ocr/1138_samples.png
#  extracting: data_ocr/1139_samples.png
#  extracting: data_ocr/1140_samples.png
#  extracting: data_ocr/1141_samples.png
#  extracting: data_ocr/1142_samples.png
#  extracting: data_ocr/1143_samples.png
#  extracting: data_ocr/1144_samples.png
#  extracting: data_ocr/1145_samples.png
#  extracting: data_ocr/1146_samples.png
#  extracting: data_ocr/1147_samples.png
#  extracting: data_ocr/1148_samples.png
#   inflating: data_ocr/1149_samples.png
#  extracting: data_ocr/1150_samples.png
#  extracting: data_ocr/1151_samples.png
#  extracting: data_ocr/1152_samples.png
#   inflating: data_ocr/1153_samples.png
#  extracting: data_ocr/1154_samples.png
#  extracting: data_ocr/1155_samples.png
#  extracting: data_ocr/1156_samples.png
#  extracting: data_ocr/1157_samples.png
#  extracting: data_ocr/1158_samples.png
#   inflating: data_ocr/1159_samples.png
#  extracting: data_ocr/1160_samples.png
#  extracting: data_ocr/1161_samples.png
#  extracting: data_ocr/1162_samples.png
#  extracting: data_ocr/1163_samples.png
#  extracting: data_ocr/1164_samples.png
#  extracting: data_ocr/1165_samples.png
#  extracting: data_ocr/1166_samples.png
#  extracting: data_ocr/1167_samples.png
#  extracting: data_ocr/1168_samples.png
# ...
#  extracting: data_ocr/1434_samples.png
#  extracting: data_ocr/1435_samples.png
#  extracting: data_ocr/1436_samples.png
#  extracting: data_ocr/1437_samples.png
#   inflating: data_ocr/1438_samples.png
#  extracting: data_ocr/1439_samples.png
#  extracting: data_ocr/1440_samples.png
#   inflating: data_ocr/1441_samples.png
#  extracting: data_ocr/1442_samples.png
#  extracting: data_ocr/1443_samples.png
#  extracting: data_ocr/1444_samples.png
#  extracting: data_ocr/1445_samples.png
#  extracting: data_ocr/1446_samples.png
#  extracting: data_ocr/1447_samples.png
#  extracting: data_ocr/1448_samples.png
#  extracting: data_ocr/1449_samples.png
#  extracting: data_ocr/1450_samples.png
#  extracting: data_ocr/1451_samples.png
#  extracting: data_ocr/1452_samples.png
#   inflating: data_ocr/1453_samples.png
#   inflating: data_ocr/1454_samples.png
#  extracting: data_ocr/1455_samples.png
#  extracting: data_ocr/1456_samples.png
#   inflating: data_ocr/1457_samples.png
#  extracting: data_ocr/1458_samples.png
#  extracting: data_ocr/1459_samples.png
#  extracting: data_ocr/1460_samples.png
#  extracting: data_ocr/1461_samples.png
#  extracting: data_ocr/1462_samples.png
#  extracting: data_ocr/1463_samples.png
#  extracting: data_ocr/1464_samples.png
#  extracting: data_ocr/1465_samples.png
#  extracting: data_ocr/1466_samples.png
#  extracting: data_ocr/1467_samples.png
#  extracting: data_ocr/1468_samples.png
#  extracting: data_ocr/1469_samples.png
#  extracting: data_ocr/1470_samples.png
#  extracting: data_ocr/1471_samples.png
#  extracting: data_ocr/1472_samples.png
#  extracting: data_ocr/1473_samples.png
#  extracting: data_ocr/1474_samples.png
#  extracting: data_ocr/1475_samples.png
#  extracting: data_ocr/1476_samples.png
#  extracting: data_ocr/1477_samples.png
#  extracting: data_ocr/1478_samples.png
#  extracting: data_ocr/1479_samples.png
#  extracting: data_ocr/1480_samples.png
#  extracting: data_ocr/1481_samples.png
#  extracting: data_ocr/1482_samples.png
#  extracting: data_ocr/1483_samples.png
#  extracting: data_ocr/1484_samples.png
#  extracting: data_ocr/1485_samples.png
#  extracting: data_ocr/1486_samples.png
#  extracting: data_ocr/1487_samples.png
#  extracting: data_ocr/1488_samples.png
#  extracting: data_ocr/1489_samples.png
#  extracting: data_ocr/1490_samples.png
#  extracting: data_ocr/1491_samples.png
#  extracting: data_ocr/1492_samples.png
#  extracting: data_ocr/1493_samples.png
#  extracting: data_ocr/1494_samples.png
#  extracting: data_ocr/1495_samples.png
#  extracting: data_ocr/1496_samples.png
#   inflating: data_ocr/1497_samples.png
#  extracting: data_ocr/1498_samples.png
#  extracting: data_ocr/1499_samples.png
#   inflating: data_ocr/1500_samples.png
#  extracting: data_ocr/1501_samples.png
#  extracting: data_ocr/1502_samples.png
#  extracting: data_ocr/1503_samples.png
#  extracting: data_ocr/1504_samples.png
#  extracting: data_ocr/1505_samples.png
#  extracting: data_ocr/1506_samples.png
#  extracting: data_ocr/1507_samples.png
#  extracting: data_ocr/1508_samples.png
#  extracting: data_ocr/1509_samples.png
#  extracting: data_ocr/1510_samples.png
#  extracting: data_ocr/1511_samples.png
#  extracting: data_ocr/1512_samples.png
#  extracting: data_ocr/1513_samples.png
#   inflating: data_ocr/1514_samples.png
#   inflating: data_ocr/1515_samples.png
#  extracting: data_ocr/1516_samples.png
#  extracting: data_ocr/1517_samples.png
#  extracting: data_ocr/1518_samples.png
#  extracting: data_ocr/1519_samples.png
#  extracting: data_ocr/1520_samples.png
#  extracting: data_ocr/1521_samples.png
#   inflating: data_ocr/1522_samples.png
#  extracting: data_ocr/1523_samples.png
#  extracting: data_ocr/1524_samples.png
#   inflating: data_ocr/1525_samples.png
#  extracting: data_ocr/1526_samples.png
#  extracting: data_ocr/1527_samples.png
#  extracting: data_ocr/1528_samples.png
#  extracting: data_ocr/1529_samples.png
#   inflating: data_ocr/1530_samples.png
#  extracting: data_ocr/1531_samples.png
#  extracting: data_ocr/1532_samples.png
#  extracting: data_ocr/1533_samples.png
#  extracting: data_ocr/1534_samples.png
#  extracting: data_ocr/1535_samples.png
#  extracting: data_ocr/1536_samples.png
#   inflating: data_ocr/1537_samples.png
#  extracting: data_ocr/1538_samples.png
#  extracting: data_ocr/1539_samples.png
#  extracting: data_ocr/1540_samples.png
#  extracting: data_ocr/1541_samples.png
#  extracting: data_ocr/1542_samples.png
#  extracting: data_ocr/1543_samples.png
#  extracting: data_ocr/1544_samples.png
#   inflating: data_ocr/1545_samples.png
#  extracting: data_ocr/1546_samples.png
#  extracting: data_ocr/1547_samples.png
#  extracting: data_ocr/1548_samples.png
#  extracting: data_ocr/1549_samples.png
#  extracting: data_ocr/1550_samples.png
#   inflating: data_ocr/1551_samples.png
#  extracting: data_ocr/1552_samples.png
#   inflating: data_ocr/1553_samples.png
#  extracting: data_ocr/1554_samples.png
#   inflating: data_ocr/1555_samples.png
#  extracting: data_ocr/1556_samples.png
#  extracting: data_ocr/1557_samples.png
#  extracting: data_ocr/1558_samples.png
#   inflating: data_ocr/1559_samples.png
#  extracting: data_ocr/1560_samples.png
#  extracting: data_ocr/1561_samples.png
#  extracting: data_ocr/1562_samples.png
#  extracting: data_ocr/1563_samples.png
#  extracting: data_ocr/1564_samples.png
#  extracting: data_ocr/1565_samples.png
#  extracting: data_ocr/1566_samples.png
#  extracting: data_ocr/1567_samples.png
#  extracting: data_ocr/1568_samples.png
#  extracting: data_ocr/1569_samples.png
#  extracting: data_ocr/1570_samples.png
#  extracting: data_ocr/1571_samples.png
#  extracting: data_ocr/1572_samples.png
#  extracting: data_ocr/1573_samples.png
#  extracting: data_ocr/1574_samples.png
#  extracting: data_ocr/1575_samples.png
#  extracting: data_ocr/1576_samples.png
#  extracting: data_ocr/1577_samples.png
#  extracting: data_ocr/1578_samples.png
#   inflating: data_ocr/1579_samples.png
#  extracting: data_ocr/1580_samples.png
#  extracting: data_ocr/1581_samples.png
#  extracting: data_ocr/1582_samples.png
#  extracting: data_ocr/1583_samples.png
#  extracting: data_ocr/1584_samples.png
#  extracting: data_ocr/1585_samples.png
#  extracting: data_ocr/1586_samples.png
#  extracting: data_ocr/1587_samples.png
#  extracting: data_ocr/1588_samples.png
#  extracting: data_ocr/1589_samples.png
#  extracting: data_ocr/1590_samples.png
#  extracting: data_ocr/1591_samples.png
#  extracting: data_ocr/1592_samples.png
#  extracting: data_ocr/1593_samples.png
#  extracting: data_ocr/1594_samples.png
#   inflating: data_ocr/1595_samples.png
#  extracting: data_ocr/1596_samples.png
#  extracting: data_ocr/1597_samples.png
#  extracting: data_ocr/1598_samples.png
#  extracting: data_ocr/1599_samples.png
#  extracting: data_ocr/1600_samples.png
#  extracting: data_ocr/1601_samples.png
#   inflating: data_ocr/1602_samples.png
#  extracting: data_ocr/1603_samples.png
#  extracting: data_ocr/1604_samples.png
#   inflating: data_ocr/1605_samples.png
#  extracting: data_ocr/1606_samples.png
#  extracting: data_ocr/1607_samples.png
#  extracting: data_ocr/1608_samples.png
#  extracting: data_ocr/1609_samples.png
#  extracting: data_ocr/1610_samples.png
#  extracting: data_ocr/1611_samples.png
#  extracting: data_ocr/1612_samples.png
#  extracting: data_ocr/1613_samples.png
#  extracting: data_ocr/1614_samples.png
#   inflating: data_ocr/1615_samples.png
#  extracting: data_ocr/1616_samples.png
#  extracting: data_ocr/1617_samples.png
#  extracting: data_ocr/1618_samples.png
#  extracting: data_ocr/1619_samples.png
#  extracting: data_ocr/1620_samples.png
#  extracting: data_ocr/1621_samples.png
#  extracting: data_ocr/1622_samples.png
#  extracting: data_ocr/1623_samples.png
#  extracting: data_ocr/1624_samples.png
#  extracting: data_ocr/1625_samples.png
#  extracting: data_ocr/1626_samples.png
#  extracting: data_ocr/1627_samples.png
#  extracting: data_ocr/1628_samples.png
#  extracting: data_ocr/1629_samples.png
#  extracting: data_ocr/1630_samples.png
#  extracting: data_ocr/1631_samples.png
#  extracting: data_ocr/1632_samples.png
#  extracting: data_ocr/1633_samples.png
#  extracting: data_ocr/1634_samples.png
#  extracting: data_ocr/1635_samples.png
#  extracting: data_ocr/1636_samples.png
#  extracting: data_ocr/1637_samples.png
#   inflating: data_ocr/1638_samples.png
#   inflating: data_ocr/1639_samples.png
#  extracting: data_ocr/1640_samples.png
#  extracting: data_ocr/1641_samples.png
#  extracting: data_ocr/1642_samples.png
#   inflating: data_ocr/1643_samples.png
#  extracting: data_ocr/1644_samples.png
#  extracting: data_ocr/1645_samples.png
#   inflating: data_ocr/1646_samples.png
#  extracting: data_ocr/1647_samples.png
#  extracting: data_ocr/1648_samples.png
#  extracting: data_ocr/1649_samples.png
#  extracting: data_ocr/1650_samples.png
#  extracting: data_ocr/1651_samples.png
#  extracting: data_ocr/1652_samples.png
#  extracting: data_ocr/1653_samples.png
#   inflating: data_ocr/1654_samples.png
#  extracting: data_ocr/1655_samples.png
#  extracting: data_ocr/1656_samples.png
#  extracting: data_ocr/1657_samples.png
#   inflating: data_ocr/1658_samples.png
#  extracting: data_ocr/1659_samples.png
#  extracting: data_ocr/1660_samples.png
#   inflating: data_ocr/1661_samples.png
#   inflating: data_ocr/1662_samples.png
#  extracting: data_ocr/1663_samples.png
#  extracting: data_ocr/1664_samples.png
#  extracting: data_ocr/1665_samples.png
#  extracting: data_ocr/1666_samples.png
#  extracting: data_ocr/1667_samples.png
#  extracting: data_ocr/1668_samples.png
#  extracting: data_ocr/1669_samples.png
#  extracting: data_ocr/1670_samples.png
#  extracting: data_ocr/1671_samples.png
#  extracting: data_ocr/1672_samples.png
#  extracting: data_ocr/1673_samples.png
#  extracting: data_ocr/1674_samples.png
#  extracting: data_ocr/1675_samples.png
#  extracting: data_ocr/1676_samples.png
#  extracting: data_ocr/1677_samples.png
#  extracting: data_ocr/1678_samples.png
#   inflating: data_ocr/1679_samples.png
#  extracting: data_ocr/1680_samples.png
#  extracting: data_ocr/1681_samples.png
#  extracting: data_ocr/1682_samples.png
#  extracting: data_ocr/1683_samples.png
#   inflating: data_ocr/1684_samples.png
#  extracting: data_ocr/1685_samples.png
#  extracting: data_ocr/1686_samples.png
#  extracting: data_ocr/1687_samples.png
#  extracting: data_ocr/1688_samples.png
#  extracting: data_ocr/1689_samples.png
#   inflating: data_ocr/1690_samples.png
#  extracting: data_ocr/1691_samples.png
#  extracting: data_ocr/1692_samples.png
#  extracting: data_ocr/1693_samples.png
#  extracting: data_ocr/1694_samples.png
#  extracting: data_ocr/1695_samples.png
#  extracting: data_ocr/1696_samples.png
#  extracting: data_ocr/1697_samples.png
#  extracting: data_ocr/1698_samples.png
#  extracting: data_ocr/1699_samples.png
#  extracting: data_ocr/1700_samples.png
#  extracting: data_ocr/1701_samples.png
#  extracting: data_ocr/1702_samples.png
#  extracting: data_ocr/1703_samples.png
#  extracting: data_ocr/1704_samples.png
#  extracting: data_ocr/1705_samples.png
#  extracting: data_ocr/1706_samples.png
#  extracting: data_ocr/1707_samples.png
#   inflating: data_ocr/1708_samples.png
#  extracting: data_ocr/1709_samples.png
#  extracting: data_ocr/1710_samples.png
#  extracting: data_ocr/1711_samples.png
#  extracting: data_ocr/1712_samples.png
#  extracting: data_ocr/1713_samples.png
#  extracting: data_ocr/1714_samples.png
#  extracting: data_ocr/1715_samples.png
#  extracting: data_ocr/1716_samples.png
#  extracting: data_ocr/1717_samples.png
#  extracting: data_ocr/1718_samples.png
#  extracting: data_ocr/1719_samples.png
#  extracting: data_ocr/1720_samples.png
#   inflating: data_ocr/1721_samples.png
#  extracting: data_ocr/1722_samples.png
#  extracting: data_ocr/1723_samples.png
#  extracting: data_ocr/1724_samples.png
#  extracting: data_ocr/1725_samples.png
#  extracting: data_ocr/1726_samples.png
#  extracting: data_ocr/1727_samples.png
#  extracting: data_ocr/1728_samples.png
#  extracting: data_ocr/1729_samples.png
#  extracting: data_ocr/1730_samples.png
#  extracting: data_ocr/1731_samples.png
#  extracting: data_ocr/1732_samples.png
#  extracting: data_ocr/1733_samples.png
#  extracting: data_ocr/1734_samples.png
#  extracting: data_ocr/1735_samples.png
#  extracting: data_ocr/1736_samples.png
#  extracting: data_ocr/1737_samples.png
#  extracting: data_ocr/1738_samples.png
#  extracting: data_ocr/1739_samples.png
#  extracting: data_ocr/1740_samples.png
#  extracting: data_ocr/1741_samples.png
#  extracting: data_ocr/1742_samples.png
#  extracting: data_ocr/1743_samples.png
#  extracting: data_ocr/1744_samples.png
#  extracting: data_ocr/1745_samples.png
#   inflating: data_ocr/1746_samples.png
#   inflating: data_ocr/1747_samples.png
#  extracting: data_ocr/1748_samples.png
#  extracting: data_ocr/1749_samples.png
#  extracting: data_ocr/1750_samples.png
#  extracting: data_ocr/1751_samples.png
#  extracting: data_ocr/1752_samples.png
#  extracting: data_ocr/1753_samples.png
#  extracting: data_ocr/1754_samples.png
#  extracting: data_ocr/1755_samples.png
#  extracting: data_ocr/1756_samples.png
#  extracting: data_ocr/1757_samples.png
#  extracting: data_ocr/1758_samples.png
#  extracting: data_ocr/1759_samples.png
#  extracting: data_ocr/1760_samples.png
#  extracting: data_ocr/1761_samples.png
#  extracting: data_ocr/1762_samples.png
#  extracting: data_ocr/1763_samples.png
#  extracting: data_ocr/1764_samples.png
#  extracting: data_ocr/1765_samples.png
#   inflating: data_ocr/1766_samples.png
#  extracting: data_ocr/1767_samples.png
#   inflating: data_ocr/1768_samples.png
#   inflating: data_ocr/1769_samples.png
#   inflating: data_ocr/1770_samples.png
#  extracting: data_ocr/1771_samples.png
#  extracting: data_ocr/1772_samples.png
#  extracting: data_ocr/1773_samples.png
#  extracting: data_ocr/1774_samples.png
#  extracting: data_ocr/1775_samples.png
#  extracting: data_ocr/1776_samples.png
#  extracting: data_ocr/1777_samples.png
#  extracting: data_ocr/1778_samples.png
#  extracting: data_ocr/1779_samples.png
#  extracting: data_ocr/1780_samples.png
#  extracting: data_ocr/1781_samples.png
#  extracting: data_ocr/1782_samples.png
#  extracting: data_ocr/1783_samples.png
#  extracting: data_ocr/1784_samples.png
#  extracting: data_ocr/1785_samples.png
#  extracting: data_ocr/1786_samples.png
#  extracting: data_ocr/1787_samples.png
#  extracting: data_ocr/1788_samples.png
#  extracting: data_ocr/1789_samples.png
#  extracting: data_ocr/1790_samples.png
#  extracting: data_ocr/1791_samples.png
#  extracting: data_ocr/1792_samples.png
#  extracting: data_ocr/1793_samples.png
#  extracting: data_ocr/1794_samples.png
#  extracting: data_ocr/1795_samples.png
#  extracting: data_ocr/1796_samples.png
#  extracting: data_ocr/1797_samples.png
#  extracting: data_ocr/1798_samples.png
#  extracting: data_ocr/1799_samples.png
#  extracting: data_ocr/1800_samples.png
#  extracting: data_ocr/1801_samples.png
#  extracting: data_ocr/1802_samples.png
#  extracting: data_ocr/1803_samples.png
#  extracting: data_ocr/1804_samples.png
#  extracting: data_ocr/1805_samples.png
#  extracting: data_ocr/1806_samples.png
#  extracting: data_ocr/1807_samples.png
#   inflating: data_ocr/1808_samples.png
#  extracting: data_ocr/1809_samples.png
#   inflating: data_ocr/1810_samples.png
#  extracting: data_ocr/1811_samples.png
#  extracting: data_ocr/1812_samples.png
#  extracting: data_ocr/1813_samples.png
#  extracting: data_ocr/1814_samples.png
#  extracting: data_ocr/1815_samples.png
#  extracting: data_ocr/1816_samples.png
#  extracting: data_ocr/1817_samples.png
#  extracting: data_ocr/1818_samples.png
#  extracting: data_ocr/1819_samples.png
#   inflating: data_ocr/1820_samples.png
#  extracting: data_ocr/1821_samples.png
#  extracting: data_ocr/1822_samples.png
#   inflating: data_ocr/labels.json

# %%
# !rm -rf data_ocr.zip

# %% [markdown]
# # Khai báo thư viện

# %%
import json
import cv2
import os, random
import numpy as np
import itertools
import editdistance
import json


import tensorflow as tf 
import keras

from keras.preprocessing import image
from tensorflow.keras.utils import load_img, img_to_array 
from keras import applications
from keras.applications.vgg16 import preprocess_input
from sklearn.model_selection import KFold

from keras.layers import Input, Dense, Activation, Bidirectional, Dropout
from keras.layers import Reshape, Lambda, BatchNormalization
from keras.layers import LSTM
from keras.layers import add, concatenate

from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
letters = " #'()+,-./:0123456789ABCDEFGHIJKLMNOPQRSTUVWXYabcdeghiklmnopqrstuvxyzÂÊÔàáâãèéêìíòóôõùúýăĐđĩũƠơưạảấầẩậắằẵặẻẽếềểễệỉịọỏốồổỗộớờởỡợụủỨứừửữựỳỵỷỹ"
MAX_LEN = 70
SIZE = 2560, 160
CHAR_DICT = len(letters) + 1

def text_to_labels(text):
    return list(map(lambda x: letters.index(x), text))

def labels_to_text(labels):
    return ''.join(list(map(lambda x: letters[x] if x < len(letters) else "", labels)))

def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    y_pred = y_pred[:, 2:, :]
    return keras.backend.ctc_batch_cost(labels, y_pred, input_length, label_length)

def decode_batch(out):
    ret = []
    for j in range(out.shape[0]):
        out_best = list(np.argmax(out[j, 2:], 1))
        out_best = [k for k, g in itertools.groupby(out_best)]
        outstr = labels_to_text(out_best)
        ret.append(outstr)
    return ret

class TextImageGenerator:
    def __init__(self, img_dirpath, labels_path, img_w, img_h,
                 batch_size, downsample_factor, idxs, training=True, max_text_len=9, n_eraser=5):
        self.img_h = img_h
        self.img_w = img_w
        self.batch_size = batch_size
        self.max_text_len = max_text_len
        self.idxs = idxs
        self.downsample_factor = downsample_factor
        self.img_dirpath = img_dirpath                  
        self.labels= json.load(open(labels_path)) if labels_path != None else None
        self.img_dir = os.listdir(self.img_dirpath)   
        if self.idxs is not None:
            self.img_dir = [self.img_dir[idx] for idx in self.idxs]

        self.n = len(self.img_dir) # có một file labels.json                      
        if "labels.json" in self.img_dir:
          self.n -= 1
        self.indexes = list(range(self.n))
        self.cur_index = 0
        self.imgs = np.zeros((self.n, self.img_h, self.img_w, 3), dtype=np.float16)
        self.training = training
        self.texts = []

    def build_data(self):
        print(self.n, " Image Loading start... ", self.img_dirpath)
        count = 0
        for i, img_file in enumerate(self.img_dir):
            prefit = img_file.split(".")[-1]
            if prefit == "json":
              # print(prefit)
              continue
              
            img = load_img(self.img_dirpath + img_file, target_size=SIZE[::-1])
            img = img_to_array(img)
            img = preprocess_input(img).astype(np.float16)
            self.imgs[count] = img
            count+=1
            if self.labels != None: 
                self.texts.append(self.labels[img_file])
            else:
                #valid mode
                self.texts.append('')
        print("Image Loading finish...")

    def next_sample(self):
        self.cur_index += 1
        if self.cur_index >= self.n:
            self.cur_index = 0
            random.shuffle(self.indexes)
        return self.imgs[self.indexes[self.cur_index]].astype(np.float32), self.texts[self.indexes[self.cur_index]]

    def next_batch(self):
        while True:
            X_data = np.zeros([self.batch_size, self.img_w, self.img_h, 3], dtype=np.float32)     
            Y_data = np.zeros([self.batch_size, self.max_text_len], dtype=np.float32)             
            input_length = np.ones((self.batch_size, 1), dtype=np.float32) * (self.img_w // self.downsample_factor - 2)  
            label_length = np.zeros((self.batch_size, 1), dtype=np.float32)          

            for i in range(self.batch_size):
                img, text = self.next_sample()
                img = img.transpose((1, 0, 2))
                
                X_data[i] = img
                Y_data[i,:len(text)] = text_to_labels(text)
                label_length[i] = len(text)

            inputs = {
                'the_inputs': X_data,  
                'the_labels': Y_data,  
                'input_length': input_length,  
                'label_length': label_length  
            }
            outputs = {'ctc': np.zeros([self.batch_size])}  
            yield (inputs, outputs)

# %% [markdown]
# # MLP

# %%
# base nn 
def get_model(input_shape, training):
    inputs = Input(name='the_inputs', shape=input_shape, dtype='float32')
    # base_model = applications.VGG16(weights='imagenet', include_top=False)
    
    base_model = Dense(128, kernel_initializer='he_normal', activation='relu', name='mlp1')(inputs)
    # base_model = Dense(256, kernel_initializer='he_normal', activation='relu', name='mlp2')(base_model)

    # inner = base_model(inputs)
    inner = Reshape(target_shape=(int(base_model.shape[1]), -1), name='reshape')(base_model)
    inner = Dense(128, activation='relu', kernel_initializer='he_normal', name='dense1')(inner) 

    lstm = LSTM(128, return_sequences=True, kernel_initializer='he_normal', name='lstm1', dropout=0.25, recurrent_dropout=0.25)(inner) 

    y_pred = Dense(CHAR_DICT, activation='softmax', kernel_initializer='he_normal',name='dense2')(lstm)
    
    labels = Input(name='the_labels', shape=[MAX_LEN], dtype='float32')
    input_length = Input(name='input_length', shape=[1], dtype='int64')
    label_length = Input(name='label_length', shape=[1], dtype='int64')

    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred, labels, input_length, label_length])
    
    if training:
        return Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out) 
    else:
        return Model(inputs=[inputs], outputs=y_pred)

# %% [markdown]
# # CNN

# %%
# Backbone CNN 

def get_model(input_shape, training):
    inputs = Input(name='the_inputs', shape=input_shape, dtype='float32')
    base_model = applications.VGG16(weights='imagenet', include_top=False)
    
    inner = base_model(inputs)
    inner = Reshape(target_shape=(int(inner.shape[1]), -1), name='reshape')(inner)
    inner = Dense(128, activation='relu', kernel_initializer='he_normal', name='dense1')(inner) 

    lstm = LSTM(128, return_sequences=True, kernel_initializer='he_normal', name='lstm1', dropout=0.25, recurrent_dropout=0.25)(inner) 

    y_pred = Dense(CHAR_DICT, activation='softmax', kernel_initializer='he_normal',name='dense2')(lstm)
    
    labels = Input(name='the_labels', shape=[MAX_LEN], dtype='float32')
    input_length = Input(name='input_length', shape=[1], dtype='int64')
    label_length = Input(name='label_length', shape=[1], dtype='int64')

    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred, labels, input_length, label_length])
    
    if training:
        return Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out) 
    else:
        return Model(inputs=[inputs], outputs=y_pred)

# %%
def train_kfold(idx, kfold, datapath, labelpath,  epochs, batch_size, lr):
    # sess = tf.Session()
    # K.set_session(sess)
    # run_opts = tf.RunOptions(report_tensor_allocations_upon_oom = True)

    model = get_model((*SIZE, 3), training=True)
    ada = Adam(lr=lr)
    model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=ada)
    # model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=ada, options=run_opts)

    ## load data
    train_idx, valid_idx = kfold[idx]
    train_generator = TextImageGenerator(datapath, labelpath, *SIZE, batch_size, 32, train_idx, True, MAX_LEN)
    train_generator.build_data()
    valid_generator  = TextImageGenerator(datapath, labelpath, *SIZE, batch_size, 32, valid_idx, False, MAX_LEN)
    valid_generator.build_data()

    ## callbacks

    weight_path = 'best_%d.h5' % idx
    early_stop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10, mode='min', verbose=1)
    ckp = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

    # if finetune:
    #     print('load pretrain model')
    #     model.load_weights(weight_path)

    model.fit_generator(generator=train_generator.next_batch(),
                    steps_per_epoch=int(len(train_idx) / batch_size),
                    epochs=epochs,
                    callbacks=[ckp, early_stop],
                    validation_data=valid_generator.next_batch(),
                    validation_steps=int(len(valid_idx) / batch_size))
    
def train(datapath, labelpath, epochs, batch_size, lr):
    nsplits = 5

    nfiles = np.arange(len(os.listdir(datapath)))

    kfold = list(KFold(nsplits, random_state=2018, shuffle=True).split(nfiles))
    for idx in range(nsplits):
        train_kfold(idx, kfold, datapath, labelpath, epochs, batch_size, lr)

# %%
train_dir = "data_ocr/"
label_path = "data_ocr/labels.json"
epochs = 3
batch_size = 4 
os.environ["CUDA_VISIBLE_DEVICES"]=str(0)
# finetune = 0
lr = 0.001 

train(train_dir, label_path, epochs, batch_size, lr)
# Out:
# WARNING:tensorflow:Layer lstm1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1458  Image Loading start...  data_ocr/
# Image Loading finish...
# 365  Image Loading start...  data_ocr/
# Image Loading finish...
# Epoch 1/3
# <ipython-input-8-e0732b825105>:28: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator=train_generator.next_batch(),
# 364/364 [==============================] - ETA: 0s - loss: 216.3485
# Epoch 1: val_loss improved from inf to 206.81053, saving model to best_0.h5
# 364/364 [==============================] - 3757s 10s/step - loss: 216.3485 - val_loss: 206.8105
# Epoch 2/3
# 364/364 [==============================] - ETA: 0s - loss: 205.4794
# Epoch 2: val_loss did not improve from 206.81053
# 364/364 [==============================] - 3741s 10s/step - loss: 205.4794 - val_loss: 208.0319
# Epoch 3/3
# 364/364 [==============================] - ETA: 0s - loss: 204.1062
# Epoch 3: val_loss did not improve from 206.81053
# 364/364 [==============================] - 3747s 10s/step - loss: 204.1062 - val_loss: 206.8320
# WARNING:tensorflow:Layer lstm1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
